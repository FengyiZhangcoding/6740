# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
df  = pd.read_csv('data/RealEstate.csv')

# %%
df
# Out:
#         MLS            Location      Price  Bedrooms  Bathrooms  Size  \
# 0    132842       Arroyo Grande   795000.0         3          3  2371
# 1    134364         Paso Robles   399000.0         4          3  2818
# 2    135141         Paso Robles   545000.0         4          3  3032
# 3    135712           Morro Bay   909000.0         4          4  3540
# 4    136282  Santa Maria-Orcutt   109900.0         3          1  1249
# ..      ...                 ...        ...       ...        ...   ...
# 776  154562         Paso Robles   319900.0         3          3  1605
# 777  154565         Paso Robles   495000.0         3          2  1877
# 778  154566     San Luis Obispo   372000.0         3          2  1104
# 779  154575       Arroyo Grande   589000.0         3          2  1975
# 780  154580             Cambria  1100000.0         3          3  2392
#
#      Price/SQ.Ft       Status
# 0         335.30   Short Sale
# 1         141.59   Short Sale
# 2         179.75   Short Sale
# 3         256.78   Short Sale
# 4          87.99   Short Sale
# ..           ...          ...
# 776       199.31      Regular
# 777       263.72      Regular
# 778       336.96  Foreclosure
# 779       298.23      Regular
# 780       459.87      Regular
#
# [781 rows x 8 columns]

# %%
one_hot = pd.get_dummies(df['Status'])
# Drop column B as it is now encoded
df = df.drop('Status',axis = 1)
# Join the encoded df
df = df.join(one_hot)
df = df.drop('Location',axis = 1) 
df
# Out:
#         MLS      Price  Bedrooms  Bathrooms  Size  Price/SQ.Ft  Foreclosure  \
# 0    132842   795000.0         3          3  2371       335.30            0
# 1    134364   399000.0         4          3  2818       141.59            0
# 2    135141   545000.0         4          3  3032       179.75            0
# 3    135712   909000.0         4          4  3540       256.78            0
# 4    136282   109900.0         3          1  1249        87.99            0
# ..      ...        ...       ...        ...   ...          ...          ...
# 776  154562   319900.0         3          3  1605       199.31            0
# 777  154565   495000.0         3          2  1877       263.72            0
# 778  154566   372000.0         3          2  1104       336.96            1
# 779  154575   589000.0         3          2  1975       298.23            0
# 780  154580  1100000.0         3          3  2392       459.87            0
#
#      Regular  Short Sale
# 0          0           1
# 1          0           1
# 2          0           1
# 3          0           1
# 4          0           1
# ..       ...         ...
# 776        1           0
# 777        1           0
# 778        0           0
# 779        1           0
# 780        1           0
#
# [781 rows x 9 columns]

# %%
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import RepeatedKFold
X, y = df.drop('Price', axis=1).values, df['Price'].values
model = Ridge()
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
model.fit(X, y)
# Out:
# Ridge()

# %%
model.coef_
# Out:
# array([ 7.21834661e-01, -1.11368493e+04,  1.50762973e+04,  2.51783576e+02,
#         1.83973469e+03, -5.71473251e+03,  2.05842222e+04, -1.48694897e+04])

# %%
alphas = np.logspace(-3, -1, 30)
scores = [cross_val_score(model(alpha), X, y, cv=3).mean()
        for alpha in alphas]
plt.plot(alphas, scores, label=model.__name__)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-3ca421c2ee02> in <module>
#       1 alphas = np.logspace(-3, -1, 30)
# ----> 2 scores = [cross_val_score(model(alpha), X, y, cv=3).mean()
#       3         for alpha in alphas]
#       4 plt.plot(alphas, scores, label=model.__name__)
#
# <ipython-input-34-3ca421c2ee02> in <listcomp>(.0)
#       1 alphas = np.logspace(-3, -1, 30)
# ----> 2 scores = [cross_val_score(model(alpha), X, y, cv=3).mean()
#       3         for alpha in alphas]
#       4 plt.plot(alphas, scores, label=model.__name__)
#
# TypeError: 'Ridge' object is not callable

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge, Lasso

for Model in [Ridge, Lasso]:
    model = Model()
    print('%s: %s' % (Model.__name__,
                      cross_val_score(model, X, y).mean()))
# Out:
# Ridge: 0.8084479109790037
# Lasso: 0.8087238601803823

# %%
# %%time
import numpy as np
from matplotlib import pyplot as plt

alphas = myList = list(range(1, 1000))

plt.figure(figsize=(5, 3))

for Model in [Lasso, Ridge]:
    scores = [cross_val_score(Model(alpha), X, y, cv=5).mean()
            for alpha in alphas]
    plt.plot(alphas, scores, label=Model.__name__)

plt.legend(loc='lower left')
plt.xlabel('alpha')
plt.ylabel('cross validation score')
plt.tight_layout()
plt.show()
# Out:
# Wall time: 17.6 s

# %%
Model(Ridge).R2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-7673381acf30> in <module>
# ----> 1 Model(Ridge).R2
#
# AttributeError: 'Ridge' object has no attribute 'R2'
